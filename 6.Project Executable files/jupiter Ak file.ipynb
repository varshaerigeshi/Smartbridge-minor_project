# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Reading the file

# %%
df = pd.read_csv('automative_kickstart.csv')

# %%
# Checking dataset info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374853 entries, 0 to 374852
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ID           374853 non-null  int64
#  1   Name         374853 non-null  object
#  2   Category     374853 non-null  object
#  3   Subcategory  374853 non-null  object
#  4   Country      374853 non-null  object
#  5   Launched     374853 non-null  object
#  6   Deadline     374853 non-null  object
#  7   Goal         374853 non-null  int64
#  8   Pledged      374853 non-null  int64
#  9   Backers      374853 non-null  int64
#  10  State        374853 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 31.5+ MB

# %%
#Data cleaning

# %%
df.head(5)
# Out:
#            ID                                               Name  \
# 0  1860890148  Grace Jones Does Not Give A F$#% T-Shirt (limi...
# 1   709707365                     CRYSTAL ANTLERS UNTITLED MOVIE
# 2  1703704063                                drawing for dollars
# 3      727286                       Offline Wikipedia iPhone app
# 4  1622952265                                         Pantshirts
#
#        Category   Subcategory        Country             Launched    Deadline  \
# 0       Fashion       Fashion  United States  2009-04-21 21:02:48  2009-05-31
# 1  Film & Video        Shorts  United States  2009-04-23 00:07:53  2009-07-20
# 2           Art  Illustration  United States  2009-04-24 21:52:03  2009-05-03
# 3    Technology      Software  United States  2009-04-25 17:36:21  2009-07-14
# 4       Fashion       Fashion  United States  2009-04-27 14:10:39  2009-05-26
#
#     Goal  Pledged  Backers       State
# 0   1000      625       30      Failed
# ...

# %%
#Checking the no of rows and column and defining the column names

# %%
print("Shape of the dataset:", df.shape,'\n')
print("Total number of rows (excluding column name):",df.shape[0],'\n')
print("Total number of column:",df.shape[1],'\n')
print("Columns name",df.columns)
# Out:
# Shape of the dataset: (374853, 11)
#
# Total number of rows (excluding column name): 374853
#
# Total number of column: 11
#
# Columns name Index(['ID', 'Name', 'Category', 'Subcategory', 'Country', 'Launched',
#        'Deadline', 'Goal', 'Pledged', 'Backers', 'State'],
#       dtype='object')

# %%
# fing the rows and columns of dataset

# %%
df.shape
# Out:
# (374853, 11)

# %%
#Decribibg all showing all the data of dataset

# %%
df.describe(include="all")
# Out:
#                   ID                      Name      Category     Subcategory  \
# count   3.748530e+05                    374853        374853          374853
# unique           NaN                    372061            15             159
# top              NaN  New EP/Music Development  Film & Video  Product Design
# freq             NaN                        13         62694           22310
# mean    1.074656e+09                       NaN           NaN             NaN
# std     6.191377e+08                       NaN           NaN             NaN
# min     5.971000e+03                       NaN           NaN             NaN
# 25%     5.380728e+08                       NaN           NaN             NaN
# 50%     1.075300e+09                       NaN           NaN             NaN
# 75%     1.610149e+09                       NaN           NaN             NaN
# max     2.147476e+09                       NaN           NaN             NaN
#
# ...

# %%
#Data preparation

# %%
#Finding null values

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Category       0
# Subcategory    0
# Country        0
# Launched       0
# Deadline       0
# Goal           0
# Pledged        0
# Backers        0
# State          0
# dtype: int64

# %%
#indicate duplicate values and reflecting the sum

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#checking for no of zeroes in each column

# %%
for i in df.columns:
    print(i,len(df[df[i]==0]))
# Out:
# ID 0
# Name 0
# Category 0
# Subcategory 0
# Country 0
# Launched 0
# Deadline 0
# Goal 4
# Pledged 51810
# Backers 51804
# State 0

# %%
#Exploring the country column in data frame

# %%
df.Country.value_counts()
# Out:
# Country
# United States     292618
# United Kingdom     33671
# Canada             14756
# Australia           7839
# Germany             4171
# France              2939
# Italy               2878
# Netherlands         2868
# Spain               2276
# Sweden              1757
# Mexico              1752
# New Zealand         1447
# Denmark             1113
# Ireland              811
# Switzerland          760
# Norway               708
# Hong Kong            618
# Belgium              617
# Austria              597
# Singapore            555
# Luxembourg            62
# Japan                 40
# Name: count, dtype: int64

# %%
df.Backers.nlargest(10)
# Out:
# 194479    219382
# 305209    154926
# 144325    105857
# 87484      91585
# 42006      87142
# 312492     85581
# 203744     78471
# 86616      74405
# 68784      73986
# 220188     73206
# Name: Backers, dtype: int64

# %%
# Adding a new column

# %%
df['Year']=pd.DatetimeIndex(df['Launched']).year

# %%
df.head(3)
# Out:
#            ID                                               Name  \
# 0  1860890148  Grace Jones Does Not Give A F$#% T-Shirt (limi...
# 1   709707365                     CRYSTAL ANTLERS UNTITLED MOVIE
# 2  1703704063                                drawing for dollars
#
#        Category   Subcategory        Country             Launched    Deadline  \
# 0       Fashion       Fashion  United States  2009-04-21 21:02:48  2009-05-31
# 1  Film & Video        Shorts  United States  2009-04-23 00:07:53  2009-07-20
# 2           Art  Illustration  United States  2009-04-24 21:52:03  2009-05-03
#
#     Goal  Pledged  Backers       State  Year
# 0   1000      625       30      Failed  2009
# 1  80000       22        3      Failed  2009
# 2     20       35        3  Successful  2009

# %%
#Dropping unncessary columns(Name,ID,Launched,Deadline) from dataset

# %%
df1=df.drop(['Name','ID','Launched','Deadline'],axis=1)
df1
# Out:
#             Category     Subcategory        Country   Goal  Pledged  Backers  \
# 0            Fashion         Fashion  United States   1000      625       30
# 1       Film & Video          Shorts  United States  80000       22        3
# 2                Art    Illustration  United States     20       35        3
# 3         Technology        Software  United States     99      145       25
# 4            Fashion         Fashion  United States   1900      387       10
# ...              ...             ...            ...    ...      ...      ...
# 374848         Music         Hip-Hop  United States    500        0        0
# 374849        Design  Product Design  United States  15000      269        8
# 374850          Food            Food  United States  10000      165        3
# 374851           Art             Art  United States    650        7        1
# 374852         Games  Tabletop Games          Spain  24274     4483       82
#
#              State  Year
# ...

# %%
# checking modified dataset

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374853 entries, 0 to 374852
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Category     374853 non-null  object
#  1   Subcategory  374853 non-null  object
#  2   Country      374853 non-null  object
#  3   Goal         374853 non-null  int64
#  4   Pledged      374853 non-null  int64
#  5   Backers      374853 non-null  int64
#  6   State        374853 non-null  object
#  7   Year         374853 non-null  int32
# dtypes: int32(1), int64(3), object(4)
# memory usage: 21.4+ MB

# %% [markdown]
# #  FINDING OUTLIERS AND RESOLVING THEM

# %%
# finding and solving outlier of Goal column

# %%
sns.boxplot(df1['Goal'])
# Out:
# <Axes: ylabel='Goal'>

# %%
IQR = df1['Goal'].quantile(0.75)-df1['Goal'].quantile(0.25)
IQR
# Out:
# 14000.0

# %%
lowerBound=df1['Goal'].quantile(0.25)-(1.5*IQR)
lowerBound
# Out:
# -19000.0

# %%
upperBound=df1['Goal'].quantile(0.75)+(1.5*IQR)
upperBound
# Out:
# 37000.0

# %%
df1['Goal']=np.where(df1['Goal']>upperBound,upperBound,df1['Goal'])

# %%
sns.boxplot(df1['Goal'])
# Out:
# <Axes: ylabel='Goal'>

# %%
#Finding and solving outliers of Pledged column

# %%
sns.boxplot(df1['Pledged'])
# Out:
# <Axes: ylabel='Pledged'>

# %%
#checking for missing values

# %%
df.dropna()
# Out:
#                 ID                                               Name  \
# 0       1860890148  Grace Jones Does Not Give A F$#% T-Shirt (limi...
# 1        709707365                     CRYSTAL ANTLERS UNTITLED MOVIE
# 2       1703704063                                drawing for dollars
# 3           727286                       Offline Wikipedia iPhone app
# 4       1622952265                                         Pantshirts
# ...            ...                                                ...
# 374848  1486845240                  Americas Got Talent - Serious MAK
# 374849   974738310  EVO Planner: The World's First Personalized Fl...
# 374850  2106246194    Help save La Gattara, Arizona's first Cat Cafe!
# 374851  1830173355                                Digital Dagger Coin
# 374852  1339173863                              Spirits of the Forest
#
#             Category     Subcategory        Country             Launched  \
# ...

# %%
#checking for repeated values in columns

# %%
df.dropna(axis=1)
# Out:
#                 ID                                               Name  \
# 0       1860890148  Grace Jones Does Not Give A F$#% T-Shirt (limi...
# 1        709707365                     CRYSTAL ANTLERS UNTITLED MOVIE
# 2       1703704063                                drawing for dollars
# 3           727286                       Offline Wikipedia iPhone app
# 4       1622952265                                         Pantshirts
# ...            ...                                                ...
# 374848  1486845240                  Americas Got Talent - Serious MAK
# 374849   974738310  EVO Planner: The World's First Personalized Fl...
# 374850  2106246194    Help save La Gattara, Arizona's first Cat Cafe!
# 374851  1830173355                                Digital Dagger Coin
# 374852  1339173863                              Spirits of the Forest
#
#             Category     Subcategory        Country             Launched  \
# ...

# %%
IQR = df1['Pledged'].quantile(0.75)-df1['Pledged'].quantile(0.25)
IQR
# Out:
# 4020.0

# %%
lowerBound=df1['Pledged'].quantile(0.25)-(1.5*IQR)
lowerBound
# Out:
# -5999.0

# %%
upperBound=df1['Pledged'].quantile(0.75)+(1.5*IQR)
upperBound
# Out:
# 10081.0

# %%
df1['Pledged']=np.where(df1['Pledged']>upperBound,upperBound,df1['Pledged'])

# %%
sns.boxplot(df1['Pledged'])
# Out:
# <Axes: ylabel='Pledged'>

# %%
#Checking and resolving outliers from Backers

# %%
sns.boxplot(df1['Backers'])
# Out:
# <Axes: ylabel='Backers'>

# %%
IQR = df1['Backers'].quantile(0.75)-df1['Backers'].quantile(0.25)
IQR
# Out:
# 55.0

# %%
lowerBound=df1['Backers'].quantile(0.25)-(1.5*IQR)
lowerBound
# Out:
# -80.5

# %%
upperBound=df1['Backers'].quantile(0.75)+(1.5*IQR)
upperBound
# Out:
# 139.5

# %%
df1['Backers']=np.where(df1['Backers']>upperBound,upperBound,df1['Backers'])

# %%
sns.boxplot(df1['Backers'])
# Out:
# <Axes: ylabel='Backers'>

# %%
#Finding and resolving outliers from Year column

# %%
sns.boxplot(df1['Year'])
# Out:
# <Axes: ylabel='Year'>

# %%
df1.describe(include="all")
# Out:
#             Category     Subcategory        Country           Goal  \
# count         374853          374853         374853  374853.000000
# unique            15             159             22            NaN
# top     Film & Video  Product Design  United States            NaN
# freq           62694           22310         292618            NaN
# mean             NaN             NaN            NaN   11254.407245
# std              NaN             NaN            NaN   12232.449512
# min              NaN             NaN            NaN       0.000000
# 25%              NaN             NaN            NaN    2000.000000
# 50%              NaN             NaN            NaN    5500.000000
# 75%              NaN             NaN            NaN   16000.000000
# max              NaN             NaN            NaN   37000.000000
#
#               Pledged        Backers   State           Year
# count   374853.000000  374853.000000  374853  374853.000000
# ...

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# #Univariant Analysis

# %%
import seaborn as sns
sns.set(rc = {"figure.figsize":(50,20)})
sns.displot(data = df, x = "State");

# %%
category_count = df['Category'].value_counts()
plt.figure(figsize=(40,30))
sns.barplot(x=category_count.index,y=category_count.values, alpha=1.0)
plt.title('Frequency of Project Categories', fontsize=40)
plt.ylabel('Frequency of Occurences', fontsize = 30)
plt.xlabel('category', fontsize=30)
plt.show()

# %%
ax1 = plt.subplot(111)
df.groupby(["Year","Category"])["Goal"].mean().unstack().plot(kind='bar',figsize=(12,8),stacked=True, width=0.8,colormap='rainbow')

plt.title('average Goal per Category by year \n',fontsize=22)
plt.xlabel('Year', fontsize=20)
plt.ylabel('Goal', fontsize=20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
sns.kdeplot(df["Backers"], color = "green", fill=True)
plt.show()
plt.figure()

# %%
le = LabelEncoder()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374853 entries, 0 to 374852
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Category     374853 non-null  object
#  1   Subcategory  374853 non-null  object
#  2   Country      374853 non-null  object
#  3   Goal         374853 non-null  float64
#  4   Pledged      374853 non-null  float64
#  5   Backers      374853 non-null  float64
#  6   State        374853 non-null  object
#  7   Year         374853 non-null  int32
# dtypes: float64(3), int32(1), object(4)
# memory usage: 21.4+ MB

# %%
df1['Category'] = le.fit_transform(df1['Category'])
df1['Subcategory'] = le.fit_transform(df1['Subcategory'])
df1['Country'] = le.fit_transform(df1['Country'])
df1['State'] = le.fit_transform(df1['State'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374853 entries, 0 to 374852
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Category     374853 non-null  int32
#  1   Subcategory  374853 non-null  int32
#  2   Country      374853 non-null  int32
#  3   Goal         374853 non-null  float64
#  4   Pledged      374853 non-null  float64
#  5   Backers      374853 non-null  float64
#  6   State        374853 non-null  int32
#  7   Year         374853 non-null  int32
# dtypes: float64(3), int32(5)
# memory usage: 15.7 MB

# %%
sns.heatmap(df1.corr(),annot=True)
# Out:
# <Axes: >

# %%
x=df1.drop(columns = ["State"], axis=1)
y=df1["State"]

# %%
x
# Out:
#         Category  Subcategory  Country     Goal  Pledged  Backers  Year
# 0              5           52       21   1000.0    625.0     30.0  2009
# 1              6          129       21  37000.0     22.0      3.0  2009
# 2              0           70       21     20.0     35.0      3.0  2009
# 3             13          131       21     99.0    145.0     25.0  2009
# 4              5           52       21   1900.0    387.0     10.0  2009
# ...          ...          ...      ...      ...      ...      ...   ...
# 374848        10           68       21    500.0      0.0      0.0  2018
# 374849         4          113       21  15000.0    269.0      8.0  2018
# 374850         7           58       21  10000.0    165.0      3.0  2018
# 374851         0           10       21    650.0      7.0      1.0  2018
# 374852         8          136       17  24274.0   4483.0     82.0  2018
#
# [374853 rows x 7 columns]

# %%
y
# Out:
# 0         1
# 1         1
# 2         3
# 3         3
# 4         1
#          ..
# 374848    2
# 374849    2
# 374850    2
# 374851    2
# 374852    2
# Name: State, Length: 374853, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler
Scale = StandardScaler()
X_standard = Scale.fit_transform(df1)

# %%
X_standard
# Out:
# array([[-0.63721416, -0.6340869 ,  0.37522943, ..., -0.14902586,
#         -0.58204005, -2.71397736],
#        [-0.38179634,  1.06591714,  0.37522943, ..., -0.71078936,
#         -0.58204005, -2.71397736],
#        [-1.91430326, -0.23668336,  0.37522943, ..., -0.71078936,
#          1.25700291, -2.71397736],
#        ...,
#        [-0.12637851, -0.50161905,  0.37522943, ..., -0.71078936,
#          0.33748143,  1.94616419],
#        [-1.91430326, -1.56136184,  0.37522943, ..., -0.75240147,
#          0.33748143,  1.94616419],
#        [ 0.12903931,  1.22046297, -0.38238921, ...,  0.93288901,
#          0.33748143,  1.94616419]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X_standard,y,test_size=0.3,random_state = 42)
x_train.shape, x_test.shape
# Out:
# ((262397, 8), (112456, 8))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(Scaled_x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import r2_score
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
pred=lr.predict(x_test)
pred
# Out:
# array([1, 2, 1, ..., 3, 3, 1])

# %%
lg_ac=accuracy_score(y_test,pred)
lg_f1 = f1_score(y_test, pred, average='weighted')  # Options: 'micro', 'macro', 'weighted'
lg_r2=r2_score(y_test,pred)
print(lg_ac)
print(lg_f1)
print(lg_r2)
# Out:
# 0.9999911076332076
# 0.9999911049824752
# 0.9999924742390236

# %%
print('\n\n\n', classification_report(y_test,pred))
# Out:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     11661
#            1       1.00      1.00      1.00     59328
#            2       1.00      1.00      1.00       822
#            3       1.00      1.00      1.00     40124
#            4       1.00      1.00      1.00       521
#
#     accuracy                           1.00    112456
#    macro avg       1.00      1.00      1.00    112456
# weighted avg       1.00      1.00      1.00    112456

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import r2_score
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
kpred=knn.predict(x_test)
kpred
# Out:
# array([1, 2, 1, ..., 3, 3, 1])

# %%
knn_ac=accuracy_score(y_test,kpred)
knn_f1 = f1_score(y_test, kpred, average='weighted')  # Options: 'micro', 'macro', 'weighted'
knn_r2=r2_score(y_test,kpred)
print(knn_ac)
print(knn_f1)
print(knn_r2)
# Out:
# 0.998586113680017
# 0.9985568270747605
# 0.9988034040047492

# %%
print('\n\n\n', classification_report(y_test,kpred))
# Out:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     11661
#            1       1.00      1.00      1.00     59328
#            2       1.00      0.94      0.97       822
#            3       1.00      1.00      1.00     40124
#            4       1.00      0.86      0.93       521
#
#     accuracy                           1.00    112456
#    macro avg       1.00      0.96      0.98    112456
# weighted avg       1.00      1.00      1.00    112456

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import r2_score
rf=RandomForestClassifier()
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rpred=rf.predict(x_test)
rpred
# Out:
# array([1, 2, 1, ..., 3, 3, 1])

# %%
rf_ac=accuracy_score(y_test,rpred)
rf_f1 = f1_score(y_test, rpred, average='weighted')  # Options: 'micro', 'macro', 'weighted'
rf_r2=r2_score(y_test,rpred)
print(rf_ac)
print(rf_f1)
print(rf_r2)
# Out:
# 0.9999911076332076
# 0.9999911049645414
# 0.9999924742390236

# %%
print('\n\n\n', classification_report(y_test,rpred))
# Out:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     11661
#            1       1.00      1.00      1.00     59328
#            2       1.00      1.00      1.00       822
#            3       1.00      1.00      1.00     40124
#            4       1.00      1.00      1.00       521
#
#     accuracy                           1.00    112456
#    macro avg       1.00      1.00      1.00    112456
# weighted avg       1.00      1.00      1.00    112456

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import r2_score
linear_svc = LinearSVC()
linear_svc.fit(x_train, y_train)
# Out:
# C:\Users\rohan\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# LinearSVC()

# %%
spred=rf.predict(x_test)
spred
# Out:
# array([1, 2, 1, ..., 3, 3, 1])

# %%
svm_ac=accuracy_score(y_test,spred)
svm_f1 = f1_score(y_test, spred, average='weighted')  # Options: 'micro', 'macro', 'weighted'
svm_r2=r2_score(y_test,rpred)
print(svm_ac)
print(svm_f1)
print(svm_r2)
# Out:
# 0.9999911076332076
# 0.9999911049645414
# 0.9999924742390236

# %%
print('\n\n\n', classification_report(y_test,spred))
# Out:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     11661
#            1       1.00      1.00      1.00     59328
#            2       1.00      1.00      1.00       822
#            3       1.00      1.00      1.00     40124
#            4       1.00      1.00      1.00       521
#
#     accuracy                           1.00    112456
#    macro avg       1.00      1.00      1.00    112456
# weighted avg       1.00      1.00      1.00    112456

# %%
df1.head(3)
# Out:
#    Category  Subcategory  Country     Goal  Pledged  Backers  State  Year
# 0         5           52       21   1000.0    625.0     30.0      1  2009
# 1         6          129       21  37000.0     22.0      3.0      1  2009
# 2         0           70       21     20.0     35.0      3.0      3  2009

# %%
import pickle
pickle.dump(rf,open('ranf.pkl','wb'))
